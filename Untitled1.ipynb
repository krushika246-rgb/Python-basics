# %% [markdown]
# <a href="https://colab.research.google.com/github/krushika246-rgb/Python-basics/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# Enter your age: 19
# You are eligible for voting

# %%
marks = int(input("enter student marks: "))
if marks<50:
   marks = marks+ 10
   print("grace marks added.")
   print("updated marks:",marks)
else:
   print("pass")
# Out:
# enter student marks: 60
# pass
